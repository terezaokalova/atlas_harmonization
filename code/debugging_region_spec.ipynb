# %%
import pandas as pd
import numpy as np
from scipy import stats
from statsmodels.stats.multitest import fdrcorrection
import logging
import os
from typing import Dict, List, Tuple

# %%
# Global configurations
code_directory = '/Users/tereza/nishant/atlas/atlas_work_terez/atlas_harmonization/code'
os.chdir(code_directory)

RESULTS_DIR = '../results'
DATA_DIR = '../Data'
FIGURES_DIR = '../figures'

# %%
# handles class imbalance by truncating

class RegionalAnalysis:
    def __init__(self):
        self.logger = logging.getLogger(__name__)
        self.feature_columns = [
            'deltaRel_mean', 
            'thetaRel_mean', 
            'alphaRel_mean', 
            'betaRel_mean',
            'gammaRel_mean',
            'entropy_1min_mean',
            'entropy_fullts_mean'
        ]
        
        self.feature_names = {
            'deltaRel_mean': 'Delta Band (0.5-4 Hz)',
            'thetaRel_mean': 'Theta Band (4-8 Hz)',
            'alphaRel_mean': 'Alpha Band (8-13 Hz)',
            'betaRel_mean': 'Beta Band (13-30 Hz)',
            'gammaRel_mean': 'Gamma Band (30-80 Hz)',
            'entropy_1min_mean': 'Signal Entropy (1-min)',
            'entropy_fullts_mean': 'Signal Entropy (full)'
        }
        
    def load_data(self) -> Tuple[pd.DataFrame, pd.DataFrame]:
        """
        Load and prepare the regional feature data for both cohorts
        """
        try:
            # Load data with correct paths
            hup_path = os.path.join(RESULTS_DIR, 'ge_go_hup_region_features.csv')
            mni_path = os.path.join(RESULTS_DIR, 'mni_region_features.csv')
            
            print(f"Loading HUP features from: {hup_path}")
            print(f"Loading MNI features from: {mni_path}")
            
            self.hup_features = pd.read_csv(hup_path)
            self.mni_features = pd.read_csv(mni_path)
            
            # Get common regions
            self.common_regions = set(self.hup_features['roi'].unique()) & set(self.mni_features['roi'].unique())
            
            print(f"\nLoaded data:")
            print(f"HUP features shape: {self.hup_features.shape}")
            print(f"MNI features shape: {self.mni_features.shape}")
            print(f"Number of common regions: {len(self.common_regions)}")
            
            return self.hup_features, self.mni_features
            
        except FileNotFoundError as e:
            self.logger.error(f"File not found error: {str(e)}")
            print(f"\nCurrent working directory: {os.getcwd()}")
            print(f"RESULTS_DIR path: {os.path.abspath(RESULTS_DIR)}")
            raise
        except Exception as e:
            self.logger.error(f"Error loading data: {str(e)}")
            raise
    
    def prepare_paired_data(self, region: str, feature: str) -> Tuple[np.ndarray, np.ndarray]:
        """
        Prepare paired data for a specific region and feature.
        Returns arrays of equal length for valid statistical comparison.
        """
        # Get data for specific region
        hup_region_data = self.hup_features[self.hup_features['roi'] == region]
        mni_region_data = self.mni_features[self.mni_features['roi'] == region]
        
        # Group by patient and get mean values (in case of multiple electrodes per region per patient)
        hup_data = hup_region_data.groupby('patient_id')[feature].mean().values
        mni_data = mni_region_data.groupby('patient_id')[feature].mean().values
        
        # Get minimum length to ensure paired data
        min_length = min(len(hup_data), len(mni_data))
        
        if min_length < 5:  # Minimum sample size requirement
            raise ValueError(f"Insufficient samples for region {region} (HUP: {len(hup_data)}, MNI: {len(mni_data)})")
            
        # Match lengths for pairing
        hup_data = hup_data[:min_length]
        mni_data = mni_data[:min_length]
        
        return hup_data, mni_data
    
    def compute_effect_size(self, hup_data: np.ndarray, mni_data: np.ndarray) -> float:
        """
        Compute Cohen's d effect size for paired data
        """
        diff = hup_data - mni_data
        d = np.mean(diff) / np.std(diff)
        return d
    
    def analyze_regions(self) -> pd.DataFrame:
        """
        Perform paired regional analysis between HUP and MNI cohorts
        """
        results = []
        
        for region in self.common_regions:
            self.logger.info(f"Analyzing region: {region}")
            
            for feature in self.feature_columns:
                try:
                    # Get paired data
                    hup_data, mni_data = self.prepare_paired_data(region, feature)
                    
                    # Perform Wilcoxon signed-rank test (paired test)
                    statistic, pvalue = stats.wilcoxon(hup_data, mni_data)
                    
                    # Compute effect size
                    effect_size = self.compute_effect_size(hup_data, mni_data)
                    
                    results.append({
                        'region': region,
                        'feature': feature,
                        'statistic': statistic,
                        'pvalue': pvalue,
                        'effect_size': effect_size,
                        'hup_mean': np.mean(hup_data),
                        'mni_mean': np.mean(mni_data),
                        'hup_std': np.std(hup_data),
                        'mni_std': np.std(mni_data),
                        'n_samples': len(hup_data)
                    })
                    
                except ValueError as e:
                    self.logger.warning(f"Skipping {region}-{feature}: {str(e)}")
                except Exception as e:
                    self.logger.error(f"Error processing {region}-{feature}: {str(e)}")
        
        # Create results DataFrame
        results_df = pd.DataFrame(results)
        
        if len(results_df) > 0:
            # Apply FDR correction
            _, fdr_pvals = fdrcorrection(results_df['pvalue'])
            results_df['pvalue_fdr'] = fdr_pvals
        else:
            self.logger.warning("No results generated from analysis")
            
        return results_df
    
    def summarize_results(self, results_df: pd.DataFrame):
        """
        Print summary of significant findings
        """
        if len(results_df) == 0:
            print("No results to summarize")
            return
            
        print("\nRegional Analysis Summary")
        print("=" * 50)
        
        for feature in self.feature_columns:
            feature_results = results_df[results_df['feature'] == feature]
            sig_results = feature_results[feature_results['pvalue_fdr'] < 0.05]
            
            print(f"\n{self.feature_names[feature]}:")
            print(f"- {len(sig_results)} regions show significant differences")
            
            if len(sig_results) > 0:
                sig_results = sig_results.sort_values('effect_size', key=abs, ascending=False)
                print("\nTop regions with largest differences:")
                
                for _, row in sig_results.head(3).iterrows():
                    direction = "higher in HUP" if row['effect_size'] > 0 else "higher in MNI"
                    effect_mag = "large" if abs(row['effect_size']) > 0.8 else \
                                "medium" if abs(row['effect_size']) > 0.5 else "small"
                    
                    print(f"  * {row['region']}: {effect_mag} effect {direction}")
                    print(f"    (p={row['pvalue_fdr']:.3e}, d={row['effect_size']:.2f}, n={row['n_samples']})")

# %%
def main():
    # Set up logging
    logging.basicConfig(level=logging.INFO)
    
    try:
        # Initialize analysis
        analysis = RegionalAnalysis()
        
        # Load data
        analysis.load_data()
        
        # Perform analysis
        results = analysis.analyze_regions()
        
        # Summarize results
        analysis.summarize_results(results)
        
       
    except Exception as e:
        print(f"Error in main execution: {str(e)}")
        raise

if __name__ == "__main__":
    main()
# Out:
# INFO:__main__:Analyzing region: Left-Amygdala
# WARNING:__main__:Skipping Left-Amygdala-deltaRel_mean: Insufficient samples for region Left-Amygdala (HUP: 4, MNI: 1)
# WARNING:__main__:Skipping Left-Amygdala-thetaRel_mean: Insufficient samples for region Left-Amygdala (HUP: 4, MNI: 1)
# WARNING:__main__:Skipping Left-Amygdala-alphaRel_mean: Insufficient samples for region Left-Amygdala (HUP: 4, MNI: 1)
# WARNING:__main__:Skipping Left-Amygdala-betaRel_mean: Insufficient samples for region Left-Amygdala (HUP: 4, MNI: 1)
# WARNING:__main__:Skipping Left-Amygdala-gammaRel_mean: Insufficient samples for region Left-Amygdala (HUP: 4, MNI: 1)
# WARNING:__main__:Skipping Left-Amygdala-entropy_1min_mean: Insufficient samples for region Left-Amygdala (HUP: 4, MNI: 1)
# WARNING:__main__:Skipping Left-Amygdala-entropy_fullts_mean: Insufficient samples for region Left-Amygdala (HUP: 4, MNI: 1)
# INFO:__main__:Analyzing region: ctx-lh-caudalmiddlefrontal
# INFO:__main__:Analyzing region: ctx-rh-rostralanteriorcingulate
# WARNING:__main__:Skipping ctx-rh-rostralanteriorcingulate-deltaRel_mean: Insufficient samples for region ctx-rh-rostralanteriorcingulate (HUP: 1, MNI: 4)
# WARNING:__main__:Skipping ctx-rh-rostralanteriorcingulate-thetaRel_mean: Insufficient samples for region ctx-rh-rostralanteriorcingulate (HUP: 1, MNI: 4)
# WARNING:__main__:Skipping ctx-rh-rostralanteriorcingulate-alphaRel_mean: Insufficient samples for region ctx-rh-rostralanteriorcingulate (HUP: 1, MNI: 4)
# WARNING:__main__:Skipping ctx-rh-rostralanteriorcingulate-betaRel_mean: Insufficient samples for region ctx-rh-rostralanteriorcingulate (HUP: 1, MNI: 4)
# WARNING:__main__:Skipping ctx-rh-rostralanteriorcingulate-gammaRel_mean: Insufficient samples for region ctx-rh-rostralanteriorcingulate (HUP: 1, MNI: 4)
# WARNING:__main__:Skipping ctx-rh-rostralanteriorcingulate-entropy_1min_mean: Insufficient samples for region ctx-rh-rostralanteriorcingulate (HUP: 1, MNI: 4)
# WARNING:__main__:Skipping ctx-rh-rostralanteriorcingulate-entropy_fullts_mean: Insufficient samples for region ctx-rh-rostralanteriorcingulate (HUP: 1, MNI: 4)
# INFO:__main__:Analyzing region: ctx-lh-inferiortemporal
# INFO:__main__:Analyzing region: ctx-lh-parsopercularis
# INFO:__main__:Analyzing region: ctx-lh-middletemporal
# INFO:__main__:Analyzing region: Left-Hippocampus
# INFO:__main__:Analyzing region: ctx-lh-lateraloccipital
# WARNING:__main__:Skipping ctx-lh-lateraloccipital-deltaRel_mean: Insufficient samples for region ctx-lh-lateraloccipital (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-lh-lateraloccipital-thetaRel_mean: Insufficient samples for region ctx-lh-lateraloccipital (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-lh-lateraloccipital-alphaRel_mean: Insufficient samples for region ctx-lh-lateraloccipital (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-lh-lateraloccipital-betaRel_mean: Insufficient samples for region ctx-lh-lateraloccipital (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-lh-lateraloccipital-gammaRel_mean: Insufficient samples for region ctx-lh-lateraloccipital (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-lh-lateraloccipital-entropy_1min_mean: Insufficient samples for region ctx-lh-lateraloccipital (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-lh-lateraloccipital-entropy_fullts_mean: Insufficient samples for region ctx-lh-lateraloccipital (HUP: 3, MNI: 7)
# Loading HUP features from: ../results/ge_go_hup_region_features.csv
# Loading MNI features from: ../results/mni_region_features.csv
#
# Loaded data:
# HUP features shape: (398, 10)
# MNI features shape: (639, 10)
# Number of common regions: 57
# INFO:__main__:Analyzing region: Left-Putamen
# WARNING:__main__:Skipping Left-Putamen-deltaRel_mean: Insufficient samples for region Left-Putamen (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping Left-Putamen-thetaRel_mean: Insufficient samples for region Left-Putamen (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping Left-Putamen-alphaRel_mean: Insufficient samples for region Left-Putamen (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping Left-Putamen-betaRel_mean: Insufficient samples for region Left-Putamen (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping Left-Putamen-gammaRel_mean: Insufficient samples for region Left-Putamen (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping Left-Putamen-entropy_1min_mean: Insufficient samples for region Left-Putamen (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping Left-Putamen-entropy_fullts_mean: Insufficient samples for region Left-Putamen (HUP: 2, MNI: 3)
# INFO:__main__:Analyzing region: ctx-lh-posteriorcingulate
# WARNING:__main__:Skipping ctx-lh-posteriorcingulate-deltaRel_mean: Insufficient samples for region ctx-lh-posteriorcingulate (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-posteriorcingulate-thetaRel_mean: Insufficient samples for region ctx-lh-posteriorcingulate (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-posteriorcingulate-alphaRel_mean: Insufficient samples for region ctx-lh-posteriorcingulate (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-posteriorcingulate-betaRel_mean: Insufficient samples for region ctx-lh-posteriorcingulate (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-posteriorcingulate-gammaRel_mean: Insufficient samples for region ctx-lh-posteriorcingulate (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-posteriorcingulate-entropy_1min_mean: Insufficient samples for region ctx-lh-posteriorcingulate (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-posteriorcingulate-entropy_fullts_mean: Insufficient samples for region ctx-lh-posteriorcingulate (HUP: 1, MNI: 3)
# INFO:__main__:Analyzing region: ctx-rh-postcentral
# INFO:__main__:Analyzing region: ctx-lh-cuneus
# WARNING:__main__:Skipping ctx-lh-cuneus-deltaRel_mean: Insufficient samples for region ctx-lh-cuneus (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-cuneus-thetaRel_mean: Insufficient samples for region ctx-lh-cuneus (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-cuneus-alphaRel_mean: Insufficient samples for region ctx-lh-cuneus (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-cuneus-betaRel_mean: Insufficient samples for region ctx-lh-cuneus (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-cuneus-gammaRel_mean: Insufficient samples for region ctx-lh-cuneus (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-cuneus-entropy_1min_mean: Insufficient samples for region ctx-lh-cuneus (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-cuneus-entropy_fullts_mean: Insufficient samples for region ctx-lh-cuneus (HUP: 2, MNI: 3)
# INFO:__main__:Analyzing region: ctx-lh-precuneus
# WARNING:__main__:Skipping ctx-lh-precuneus-deltaRel_mean: Insufficient samples for region ctx-lh-precuneus (HUP: 3, MNI: 10)
# WARNING:__main__:Skipping ctx-lh-precuneus-thetaRel_mean: Insufficient samples for region ctx-lh-precuneus (HUP: 3, MNI: 10)
# WARNING:__main__:Skipping ctx-lh-precuneus-alphaRel_mean: Insufficient samples for region ctx-lh-precuneus (HUP: 3, MNI: 10)
# WARNING:__main__:Skipping ctx-lh-precuneus-betaRel_mean: Insufficient samples for region ctx-lh-precuneus (HUP: 3, MNI: 10)
# WARNING:__main__:Skipping ctx-lh-precuneus-gammaRel_mean: Insufficient samples for region ctx-lh-precuneus (HUP: 3, MNI: 10)
# WARNING:__main__:Skipping ctx-lh-precuneus-entropy_1min_mean: Insufficient samples for region ctx-lh-precuneus (HUP: 3, MNI: 10)
# WARNING:__main__:Skipping ctx-lh-precuneus-entropy_fullts_mean: Insufficient samples for region ctx-lh-precuneus (HUP: 3, MNI: 10)
# INFO:__main__:Analyzing region: ctx-rh-lateraloccipital
# INFO:__main__:Analyzing region: ctx-rh-lateralorbitofrontal
# INFO:__main__:Analyzing region: ctx-rh-fusiform
# INFO:__main__:Analyzing region: ctx-rh-medialorbitofrontal
# INFO:__main__:Analyzing region: ctx-rh-parahippocampal
# WARNING:__main__:Skipping ctx-rh-parahippocampal-deltaRel_mean: Insufficient samples for region ctx-rh-parahippocampal (HUP: 5, MNI: 2)
# WARNING:__main__:Skipping ctx-rh-parahippocampal-thetaRel_mean: Insufficient samples for region ctx-rh-parahippocampal (HUP: 5, MNI: 2)
# WARNING:__main__:Skipping ctx-rh-parahippocampal-alphaRel_mean: Insufficient samples for region ctx-rh-parahippocampal (HUP: 5, MNI: 2)
# WARNING:__main__:Skipping ctx-rh-parahippocampal-betaRel_mean: Insufficient samples for region ctx-rh-parahippocampal (HUP: 5, MNI: 2)
# WARNING:__main__:Skipping ctx-rh-parahippocampal-gammaRel_mean: Insufficient samples for region ctx-rh-parahippocampal (HUP: 5, MNI: 2)
# WARNING:__main__:Skipping ctx-rh-parahippocampal-entropy_1min_mean: Insufficient samples for region ctx-rh-parahippocampal (HUP: 5, MNI: 2)
# WARNING:__main__:Skipping ctx-rh-parahippocampal-entropy_fullts_mean: Insufficient samples for region ctx-rh-parahippocampal (HUP: 5, MNI: 2)
# INFO:__main__:Analyzing region: ctx-lh-lingual
# WARNING:__main__:Skipping ctx-lh-lingual-deltaRel_mean: Insufficient samples for region ctx-lh-lingual (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-lingual-thetaRel_mean: Insufficient samples for region ctx-lh-lingual (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-lingual-alphaRel_mean: Insufficient samples for region ctx-lh-lingual (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-lingual-betaRel_mean: Insufficient samples for region ctx-lh-lingual (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-lingual-gammaRel_mean: Insufficient samples for region ctx-lh-lingual (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-lingual-entropy_1min_mean: Insufficient samples for region ctx-lh-lingual (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-lingual-entropy_fullts_mean: Insufficient samples for region ctx-lh-lingual (HUP: 3, MNI: 6)
# INFO:__main__:Analyzing region: Right-Hippocampus
# INFO:__main__:Analyzing region: ctx-rh-superiortemporal
# INFO:__main__:Analyzing region: ctx-rh-inferiortemporal
# INFO:__main__:Analyzing region: ctx-rh-superiorfrontal
# INFO:__main__:Analyzing region: ctx-lh-fusiform
# INFO:__main__:Analyzing region: ctx-lh-insula
# WARNING:__main__:Skipping ctx-lh-insula-deltaRel_mean: Insufficient samples for region ctx-lh-insula (HUP: 4, MNI: 12)
# WARNING:__main__:Skipping ctx-lh-insula-thetaRel_mean: Insufficient samples for region ctx-lh-insula (HUP: 4, MNI: 12)
# WARNING:__main__:Skipping ctx-lh-insula-alphaRel_mean: Insufficient samples for region ctx-lh-insula (HUP: 4, MNI: 12)
# WARNING:__main__:Skipping ctx-lh-insula-betaRel_mean: Insufficient samples for region ctx-lh-insula (HUP: 4, MNI: 12)
# WARNING:__main__:Skipping ctx-lh-insula-gammaRel_mean: Insufficient samples for region ctx-lh-insula (HUP: 4, MNI: 12)
# WARNING:__main__:Skipping ctx-lh-insula-entropy_1min_mean: Insufficient samples for region ctx-lh-insula (HUP: 4, MNI: 12)
# WARNING:__main__:Skipping ctx-lh-insula-entropy_fullts_mean: Insufficient samples for region ctx-lh-insula (HUP: 4, MNI: 12)
# INFO:__main__:Analyzing region: ctx-lh-inferiorparietal
# INFO:__main__:Analyzing region: ctx-lh-lateralorbitofrontal
# WARNING:__main__:Skipping ctx-lh-lateralorbitofrontal-deltaRel_mean: Insufficient samples for region ctx-lh-lateralorbitofrontal (HUP: 3, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-lateralorbitofrontal-thetaRel_mean: Insufficient samples for region ctx-lh-lateralorbitofrontal (HUP: 3, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-lateralorbitofrontal-alphaRel_mean: Insufficient samples for region ctx-lh-lateralorbitofrontal (HUP: 3, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-lateralorbitofrontal-betaRel_mean: Insufficient samples for region ctx-lh-lateralorbitofrontal (HUP: 3, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-lateralorbitofrontal-gammaRel_mean: Insufficient samples for region ctx-lh-lateralorbitofrontal (HUP: 3, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-lateralorbitofrontal-entropy_1min_mean: Insufficient samples for region ctx-lh-lateralorbitofrontal (HUP: 3, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-lateralorbitofrontal-entropy_fullts_mean: Insufficient samples for region ctx-lh-lateralorbitofrontal (HUP: 3, MNI: 9)
# INFO:__main__:Analyzing region: ctx-lh-postcentral
# INFO:__main__:Analyzing region: ctx-lh-parstriangularis
# INFO:__main__:Analyzing region: ctx-lh-precentral
# INFO:__main__:Analyzing region: ctx-rh-precuneus
# WARNING:__main__:Skipping ctx-rh-precuneus-deltaRel_mean: Insufficient samples for region ctx-rh-precuneus (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-rh-precuneus-thetaRel_mean: Insufficient samples for region ctx-rh-precuneus (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-rh-precuneus-alphaRel_mean: Insufficient samples for region ctx-rh-precuneus (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-rh-precuneus-betaRel_mean: Insufficient samples for region ctx-rh-precuneus (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-rh-precuneus-gammaRel_mean: Insufficient samples for region ctx-rh-precuneus (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-rh-precuneus-entropy_1min_mean: Insufficient samples for region ctx-rh-precuneus (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-rh-precuneus-entropy_fullts_mean: Insufficient samples for region ctx-rh-precuneus (HUP: 2, MNI: 9)
# INFO:__main__:Analyzing region: ctx-rh-parstriangularis
# INFO:__main__:Analyzing region: ctx-rh-lingual
# WARNING:__main__:Skipping ctx-rh-lingual-deltaRel_mean: Insufficient samples for region ctx-rh-lingual (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-rh-lingual-thetaRel_mean: Insufficient samples for region ctx-rh-lingual (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-rh-lingual-alphaRel_mean: Insufficient samples for region ctx-rh-lingual (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-rh-lingual-betaRel_mean: Insufficient samples for region ctx-rh-lingual (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-rh-lingual-gammaRel_mean: Insufficient samples for region ctx-rh-lingual (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-rh-lingual-entropy_1min_mean: Insufficient samples for region ctx-rh-lingual (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-rh-lingual-entropy_fullts_mean: Insufficient samples for region ctx-rh-lingual (HUP: 3, MNI: 7)
# INFO:__main__:Analyzing region: ctx-lh-parsorbitalis
# WARNING:__main__:Skipping ctx-lh-parsorbitalis-deltaRel_mean: Insufficient samples for region ctx-lh-parsorbitalis (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-parsorbitalis-thetaRel_mean: Insufficient samples for region ctx-lh-parsorbitalis (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-parsorbitalis-alphaRel_mean: Insufficient samples for region ctx-lh-parsorbitalis (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-parsorbitalis-betaRel_mean: Insufficient samples for region ctx-lh-parsorbitalis (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-parsorbitalis-gammaRel_mean: Insufficient samples for region ctx-lh-parsorbitalis (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-parsorbitalis-entropy_1min_mean: Insufficient samples for region ctx-lh-parsorbitalis (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-parsorbitalis-entropy_fullts_mean: Insufficient samples for region ctx-lh-parsorbitalis (HUP: 1, MNI: 3)
# INFO:__main__:Analyzing region: ctx-lh-bankssts
# WARNING:__main__:Skipping ctx-lh-bankssts-deltaRel_mean: Insufficient samples for region ctx-lh-bankssts (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-lh-bankssts-thetaRel_mean: Insufficient samples for region ctx-lh-bankssts (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-lh-bankssts-alphaRel_mean: Insufficient samples for region ctx-lh-bankssts (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-lh-bankssts-betaRel_mean: Insufficient samples for region ctx-lh-bankssts (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-lh-bankssts-gammaRel_mean: Insufficient samples for region ctx-lh-bankssts (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-lh-bankssts-entropy_1min_mean: Insufficient samples for region ctx-lh-bankssts (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-lh-bankssts-entropy_fullts_mean: Insufficient samples for region ctx-lh-bankssts (HUP: 3, MNI: 8)
# INFO:__main__:Analyzing region: ctx-rh-insula
# WARNING:__main__:Skipping ctx-rh-insula-deltaRel_mean: Insufficient samples for region ctx-rh-insula (HUP: 3, MNI: 18)
# WARNING:__main__:Skipping ctx-rh-insula-thetaRel_mean: Insufficient samples for region ctx-rh-insula (HUP: 3, MNI: 18)
# WARNING:__main__:Skipping ctx-rh-insula-alphaRel_mean: Insufficient samples for region ctx-rh-insula (HUP: 3, MNI: 18)
# WARNING:__main__:Skipping ctx-rh-insula-betaRel_mean: Insufficient samples for region ctx-rh-insula (HUP: 3, MNI: 18)
# WARNING:__main__:Skipping ctx-rh-insula-gammaRel_mean: Insufficient samples for region ctx-rh-insula (HUP: 3, MNI: 18)
# WARNING:__main__:Skipping ctx-rh-insula-entropy_1min_mean: Insufficient samples for region ctx-rh-insula (HUP: 3, MNI: 18)
# WARNING:__main__:Skipping ctx-rh-insula-entropy_fullts_mean: Insufficient samples for region ctx-rh-insula (HUP: 3, MNI: 18)
# INFO:__main__:Analyzing region: ctx-rh-bankssts
# INFO:__main__:Analyzing region: ctx-rh-parsopercularis
# INFO:__main__:Analyzing region: ctx-lh-superiorparietal
# WARNING:__main__:Skipping ctx-lh-superiorparietal-deltaRel_mean: Insufficient samples for region ctx-lh-superiorparietal (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-superiorparietal-thetaRel_mean: Insufficient samples for region ctx-lh-superiorparietal (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-superiorparietal-alphaRel_mean: Insufficient samples for region ctx-lh-superiorparietal (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-superiorparietal-betaRel_mean: Insufficient samples for region ctx-lh-superiorparietal (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-superiorparietal-gammaRel_mean: Insufficient samples for region ctx-lh-superiorparietal (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-superiorparietal-entropy_1min_mean: Insufficient samples for region ctx-lh-superiorparietal (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-superiorparietal-entropy_fullts_mean: Insufficient samples for region ctx-lh-superiorparietal (HUP: 2, MNI: 9)
# INFO:__main__:Analyzing region: ctx-rh-rostralmiddlefrontal
# INFO:__main__:Analyzing region: ctx-lh-supramarginal
# INFO:__main__:Analyzing region: ctx-lh-rostralanteriorcingulate
# WARNING:__main__:Skipping ctx-lh-rostralanteriorcingulate-deltaRel_mean: Insufficient samples for region ctx-lh-rostralanteriorcingulate (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-rostralanteriorcingulate-thetaRel_mean: Insufficient samples for region ctx-lh-rostralanteriorcingulate (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-rostralanteriorcingulate-alphaRel_mean: Insufficient samples for region ctx-lh-rostralanteriorcingulate (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-rostralanteriorcingulate-betaRel_mean: Insufficient samples for region ctx-lh-rostralanteriorcingulate (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-rostralanteriorcingulate-gammaRel_mean: Insufficient samples for region ctx-lh-rostralanteriorcingulate (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-rostralanteriorcingulate-entropy_1min_mean: Insufficient samples for region ctx-lh-rostralanteriorcingulate (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-rostralanteriorcingulate-entropy_fullts_mean: Insufficient samples for region ctx-lh-rostralanteriorcingulate (HUP: 3, MNI: 6)
# INFO:__main__:Analyzing region: ctx-rh-precentral
# INFO:__main__:Analyzing region: ctx-lh-medialorbitofrontal
# INFO:__main__:Analyzing region: Right-Amygdala
# WARNING:__main__:Skipping Right-Amygdala-deltaRel_mean: Insufficient samples for region Right-Amygdala (HUP: 2, MNI: 2)
# WARNING:__main__:Skipping Right-Amygdala-thetaRel_mean: Insufficient samples for region Right-Amygdala (HUP: 2, MNI: 2)
# WARNING:__main__:Skipping Right-Amygdala-alphaRel_mean: Insufficient samples for region Right-Amygdala (HUP: 2, MNI: 2)
# WARNING:__main__:Skipping Right-Amygdala-betaRel_mean: Insufficient samples for region Right-Amygdala (HUP: 2, MNI: 2)
# WARNING:__main__:Skipping Right-Amygdala-gammaRel_mean: Insufficient samples for region Right-Amygdala (HUP: 2, MNI: 2)
# WARNING:__main__:Skipping Right-Amygdala-entropy_1min_mean: Insufficient samples for region Right-Amygdala (HUP: 2, MNI: 2)
# WARNING:__main__:Skipping Right-Amygdala-entropy_fullts_mean: Insufficient samples for region Right-Amygdala (HUP: 2, MNI: 2)
# INFO:__main__:Analyzing region: ctx-rh-inferiorparietal
# INFO:__main__:Analyzing region: Right-Putamen
# WARNING:__main__:Skipping Right-Putamen-deltaRel_mean: Insufficient samples for region Right-Putamen (HUP: 2, MNI: 1)
# WARNING:__main__:Skipping Right-Putamen-thetaRel_mean: Insufficient samples for region Right-Putamen (HUP: 2, MNI: 1)
# WARNING:__main__:Skipping Right-Putamen-alphaRel_mean: Insufficient samples for region Right-Putamen (HUP: 2, MNI: 1)
# WARNING:__main__:Skipping Right-Putamen-betaRel_mean: Insufficient samples for region Right-Putamen (HUP: 2, MNI: 1)
# WARNING:__main__:Skipping Right-Putamen-gammaRel_mean: Insufficient samples for region Right-Putamen (HUP: 2, MNI: 1)
# WARNING:__main__:Skipping Right-Putamen-entropy_1min_mean: Insufficient samples for region Right-Putamen (HUP: 2, MNI: 1)
# WARNING:__main__:Skipping Right-Putamen-entropy_fullts_mean: Insufficient samples for region Right-Putamen (HUP: 2, MNI: 1)
# INFO:__main__:Analyzing region: ctx-lh-superiorfrontal
# WARNING:__main__:Skipping ctx-lh-superiorfrontal-deltaRel_mean: Insufficient samples for region ctx-lh-superiorfrontal (HUP: 4, MNI: 16)
# WARNING:__main__:Skipping ctx-lh-superiorfrontal-thetaRel_mean: Insufficient samples for region ctx-lh-superiorfrontal (HUP: 4, MNI: 16)
# WARNING:__main__:Skipping ctx-lh-superiorfrontal-alphaRel_mean: Insufficient samples for region ctx-lh-superiorfrontal (HUP: 4, MNI: 16)
# WARNING:__main__:Skipping ctx-lh-superiorfrontal-betaRel_mean: Insufficient samples for region ctx-lh-superiorfrontal (HUP: 4, MNI: 16)
# WARNING:__main__:Skipping ctx-lh-superiorfrontal-gammaRel_mean: Insufficient samples for region ctx-lh-superiorfrontal (HUP: 4, MNI: 16)
# WARNING:__main__:Skipping ctx-lh-superiorfrontal-entropy_1min_mean: Insufficient samples for region ctx-lh-superiorfrontal (HUP: 4, MNI: 16)
# WARNING:__main__:Skipping ctx-lh-superiorfrontal-entropy_fullts_mean: Insufficient samples for region ctx-lh-superiorfrontal (HUP: 4, MNI: 16)
# INFO:__main__:Analyzing region: ctx-rh-caudalmiddlefrontal
# INFO:__main__:Analyzing region: ctx-lh-superiortemporal
# INFO:__main__:Analyzing region: ctx-rh-parsorbitalis
# WARNING:__main__:Skipping ctx-rh-parsorbitalis-deltaRel_mean: Insufficient samples for region ctx-rh-parsorbitalis (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-rh-parsorbitalis-thetaRel_mean: Insufficient samples for region ctx-rh-parsorbitalis (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-rh-parsorbitalis-alphaRel_mean: Insufficient samples for region ctx-rh-parsorbitalis (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-rh-parsorbitalis-betaRel_mean: Insufficient samples for region ctx-rh-parsorbitalis (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-rh-parsorbitalis-gammaRel_mean: Insufficient samples for region ctx-rh-parsorbitalis (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-rh-parsorbitalis-entropy_1min_mean: Insufficient samples for region ctx-rh-parsorbitalis (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-rh-parsorbitalis-entropy_fullts_mean: Insufficient samples for region ctx-rh-parsorbitalis (HUP: 3, MNI: 8)
# INFO:__main__:Analyzing region: ctx-rh-middletemporal
# INFO:__main__:Analyzing region: ctx-lh-paracentral
# WARNING:__main__:Skipping ctx-lh-paracentral-deltaRel_mean: Insufficient samples for region ctx-lh-paracentral (HUP: 1, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-paracentral-thetaRel_mean: Insufficient samples for region ctx-lh-paracentral (HUP: 1, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-paracentral-alphaRel_mean: Insufficient samples for region ctx-lh-paracentral (HUP: 1, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-paracentral-betaRel_mean: Insufficient samples for region ctx-lh-paracentral (HUP: 1, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-paracentral-gammaRel_mean: Insufficient samples for region ctx-lh-paracentral (HUP: 1, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-paracentral-entropy_1min_mean: Insufficient samples for region ctx-lh-paracentral (HUP: 1, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-paracentral-entropy_fullts_mean: Insufficient samples for region ctx-lh-paracentral (HUP: 1, MNI: 6)
# INFO:__main__:Analyzing region: ctx-lh-rostralmiddlefrontal
# INFO:__main__:Analyzing region: ctx-lh-pericalcarine
# WARNING:__main__:Skipping ctx-lh-pericalcarine-deltaRel_mean: Insufficient samples for region ctx-lh-pericalcarine (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-pericalcarine-thetaRel_mean: Insufficient samples for region ctx-lh-pericalcarine (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-pericalcarine-alphaRel_mean: Insufficient samples for region ctx-lh-pericalcarine (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-pericalcarine-betaRel_mean: Insufficient samples for region ctx-lh-pericalcarine (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-pericalcarine-gammaRel_mean: Insufficient samples for region ctx-lh-pericalcarine (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-pericalcarine-entropy_1min_mean: Insufficient samples for region ctx-lh-pericalcarine (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-pericalcarine-entropy_fullts_mean: Insufficient samples for region ctx-lh-pericalcarine (HUP: 1, MNI: 3)
# INFO:__main__:Analyzing region: ctx-rh-superiorparietal
# INFO:__main__:Analyzing region: ctx-rh-supramarginal
# Regional Analysis Summary
# ==================================================
#
# Delta Band (0.5-4 Hz):
# - 0 regions show significant differences
#
# Theta Band (4-8 Hz):
# - 0 regions show significant differences
#
# Alpha Band (8-13 Hz):
# - 0 regions show significant differences
#
# Beta Band (13-30 Hz):
# - 0 regions show significant differences
#
# Gamma Band (30-80 Hz):
# - 0 regions show significant differences
#
# Signal Entropy (1-min):
# - 0 regions show significant differences
#
# Signal Entropy (full):
# - 0 regions show significant differences

# %%
class RegionalAnalysis_unpaired:
    def __init__(self, hup_path: str = '../results/ge_go_hup_region_features.csv',
                 mni_path: str = '../results/mni_region_features.csv'):
        """
        Initialize the RegionalAnalysis class.
        
        Parameters:
        -----------
        hup_path : str
            Path to the HUP cohort data CSV file
        mni_path : str
            Path to the MNI cohort data CSV file
        """
        self.logger = logging.getLogger(__name__)
        self.hup_path = hup_path
        self.mni_path = mni_path
        
        # Initialize data attributes
        self.hup_features = None
        self.mni_features = None
        self.common_regions = None
        
        self.feature_columns = [
            'deltaRel_mean', 
            'thetaRel_mean', 
            'alphaRel_mean', 
            'betaRel_mean',
            'gammaRel_mean',
            'entropy_1min_mean',
            'entropy_fullts_mean'
        ]
        
        self.feature_names = {
            'deltaRel_mean': 'Delta Band (0.5-4 Hz)',
            'thetaRel_mean': 'Theta Band (4-8 Hz)',
            'alphaRel_mean': 'Alpha Band (8-13 Hz)',
            'betaRel_mean': 'Beta Band (13-30 Hz)',
            'gammaRel_mean': 'Gamma Band (30-80 Hz)',
            'entropy_1min_mean': 'Signal Entropy (1-min)',
            'entropy_fullts_mean': 'Signal Entropy (full)'
        }

    def load_data(self) -> Tuple[pd.DataFrame, pd.DataFrame]:
        """
        Load and prepare the regional feature data for both cohorts
        
        Returns:
        --------
        Tuple[pd.DataFrame, pd.DataFrame]
            HUP features DataFrame and MNI features DataFrame
        """
        try:
            print(f"Loading HUP features from: {self.hup_path}")
            print(f"Loading MNI features from: {self.mni_path}")
            
            self.hup_features = pd.read_csv(self.hup_path)
            self.mni_features = pd.read_csv(self.mni_path)
            
            # Get common regions
            self.common_regions = set(self.hup_features['roi'].unique()) & set(self.mni_features['roi'].unique())
            
            print(f"\nLoaded data:")
            print(f"HUP features shape: {self.hup_features.shape}")
            print(f"MNI features shape: {self.mni_features.shape}")
            print(f"Number of common regions: {len(self.common_regions)}")
            
            return self.hup_features, self.mni_features
            
        except FileNotFoundError as e:
            self.logger.error(f"File not found error: {str(e)}")
            print(f"\nCurrent working directory: {os.getcwd()}")
            raise
        except Exception as e:
            self.logger.error(f"Error loading data: {str(e)}")
            raise
    
    def prepare_unpaired_data(self, region: str, feature: str) -> Tuple[np.ndarray, np.ndarray]:
        """
        Prepare unpaired data for a specific region and feature.
        Returns full arrays for both cohorts without truncation.
        
        Parameters:
        -----------
        region : str
            Brain region to analyze
        feature : str
            Feature to analyze
            
        Returns:
        --------
        Tuple[np.ndarray, np.ndarray]
            Arrays containing HUP and MNI data for the specified region and feature
        """
        if self.hup_features is None or self.mni_features is None:
            raise ValueError("Data not loaded. Call load_data() first.")
            
        # Get data for specific region
        hup_region_data = self.hup_features[self.hup_features['roi'] == region]
        mni_region_data = self.mni_features[self.mni_features['roi'] == region]
        
        # Group by patient and get mean values
        hup_data = hup_region_data.groupby('patient_id')[feature].mean().values
        mni_data = mni_region_data.groupby('patient_id')[feature].mean().values
        
        if len(hup_data) < 5 or len(mni_data) < 5:
            raise ValueError(f"Insufficient samples for region {region} (HUP: {len(hup_data)}, MNI: {len(mni_data)})")
            
        return hup_data, mni_data
    
    def compute_effect_size(self, hup_data: np.ndarray, mni_data: np.ndarray) -> float:
        """
        Compute Cohen's d effect size for unpaired data
        
        Parameters:
        -----------
        hup_data : np.ndarray
            Array of HUP cohort data
        mni_data : np.ndarray
            Array of MNI cohort data
            
        Returns:
        --------
        float
            Cohen's d effect size
        """
        n1, n2 = len(hup_data), len(mni_data)
        var1, var2 = np.var(hup_data, ddof=1), np.var(mni_data, ddof=1)
        
        # Pooled standard deviation
        pooled_sd = np.sqrt(((n1 - 1) * var1 + (n2 - 1) * var2) / (n1 + n2 - 2))
        
        # Cohen's d
        d = (np.mean(hup_data) - np.mean(mni_data)) / pooled_sd
        return d
    
    def analyze_regions(self) -> pd.DataFrame:
        """
        Perform unpaired regional analysis between HUP and MNI cohorts
        
        Returns:
        --------
        pd.DataFrame
            Results DataFrame containing statistical analysis results
        """
        if self.common_regions is None:
            raise ValueError("Data not loaded. Call load_data() first.")
            
        results = []
        
        for region in self.common_regions:
            self.logger.info(f"Analyzing region: {region}")
            
            for feature in self.feature_columns:
                try:
                    # Get unpaired data
                    hup_data, mni_data = self.prepare_unpaired_data(region, feature)
                    
                    # Check normality
                    _, hup_norm_p = stats.shapiro(hup_data)
                    _, mni_norm_p = stats.shapiro(mni_data)
                    is_normal = (hup_norm_p > 0.05) and (mni_norm_p > 0.05)
                    
                    # Check homogeneity of variance
                    _, var_p = stats.levene(hup_data, mni_data)
                    equal_var = var_p > 0.05
                    
                    # Choose appropriate statistical test
                    if is_normal and equal_var:
                        # Use Student's t-test
                        statistic, pvalue = stats.ttest_ind(hup_data, mni_data)
                        test_used = "t-test"
                    elif is_normal and not equal_var:
                        # Use Welch's t-test
                        statistic, pvalue = stats.ttest_ind(hup_data, mni_data, equal_var=False)
                        test_used = "Welch"
                    else:
                        # Use Mann-Whitney U test
                        statistic, pvalue = stats.mannwhitneyu(hup_data, mni_data, alternative='two-sided')
                        test_used = "Mann-Whitney"
                    
                    # Compute effect size
                    effect_size = self.compute_effect_size(hup_data, mni_data)
                    
                    results.append({
                        'region': region,
                        'feature': feature,
                        'test_used': test_used,
                        'statistic': statistic,
                        'pvalue': pvalue,
                        'effect_size': effect_size,
                        'hup_mean': np.mean(hup_data),
                        'mni_mean': np.mean(mni_data),
                        'hup_std': np.std(hup_data),
                        'mni_std': np.std(mni_data),
                        'hup_n': len(hup_data),
                        'mni_n': len(mni_data)
                    })
                    
                except ValueError as e:
                    self.logger.warning(f"Skipping {region}-{feature}: {str(e)}")
                except Exception as e:
                    self.logger.error(f"Error processing {region}-{feature}: {str(e)}")
        
        # Create results DataFrame
        results_df = pd.DataFrame(results)
        
        if len(results_df) > 0:
            # Apply FDR correction
            _, fdr_pvals = fdrcorrection(results_df['pvalue'])
            results_df['pvalue_fdr'] = fdr_pvals
        
        return results_df

    def summarize_results(self, results_df: pd.DataFrame):
        """
        Print summary of significant findings
        
        Parameters:
        -----------
        results_df : pd.DataFrame
            DataFrame containing analysis results
        """
        if len(results_df) == 0:
            print("No results to summarize")
            return
            
        print("\nRegional Analysis Summary")
        print("=" * 50)
        
        for feature in self.feature_columns:
            feature_results = results_df[results_df['feature'] == feature]
            sig_results = feature_results[feature_results['pvalue_fdr'] < 0.05]
            
            print(f"\n{self.feature_names[feature]}:")
            print(f"- {len(sig_results)} regions show significant differences")
            
            if len(sig_results) > 0:
                sig_results = sig_results.sort_values('effect_size', key=abs, ascending=False)
                print("\nTop regions with largest differences:")
                
                for _, row in sig_results.head(3).iterrows():
                    direction = "higher in HUP" if row['effect_size'] > 0 else "higher in MNI"
                    effect_mag = "large" if abs(row['effect_size']) > 0.8 else \
                                "medium" if abs(row['effect_size']) > 0.5 else "small"
                    
                    print(f"  * {row['region']}: {effect_mag} effect {direction}")
                    print(f"    (p={row['pvalue_fdr']:.3e}, d={row['effect_size']:.2f}, ")
                    print(f"     HUP n={row['hup_n']}, MNI n={row['mni_n']}, test={row['test_used']})")

# %%
def main_unpaired():
    # Set up logging
    logging.basicConfig(level=logging.INFO)
    
    try:
        # Initialize analysis
        analysis = RegionalAnalysis_unpaired()
        
        # Load data
        analysis.load_data()
        
        # Perform analysis
        results = analysis.analyze_regions()
        
        # Summarize results
        analysis.summarize_results(results)
        
       
    except Exception as e:
        print(f"Error in main execution: {str(e)}")
        raise

if __name__ == "__main__":
    main_unpaired()
# Out:
# INFO:__main__:Analyzing region: Left-Amygdala
# WARNING:__main__:Skipping Left-Amygdala-deltaRel_mean: Insufficient samples for region Left-Amygdala (HUP: 4, MNI: 1)
# WARNING:__main__:Skipping Left-Amygdala-thetaRel_mean: Insufficient samples for region Left-Amygdala (HUP: 4, MNI: 1)
# WARNING:__main__:Skipping Left-Amygdala-alphaRel_mean: Insufficient samples for region Left-Amygdala (HUP: 4, MNI: 1)
# WARNING:__main__:Skipping Left-Amygdala-betaRel_mean: Insufficient samples for region Left-Amygdala (HUP: 4, MNI: 1)
# WARNING:__main__:Skipping Left-Amygdala-gammaRel_mean: Insufficient samples for region Left-Amygdala (HUP: 4, MNI: 1)
# WARNING:__main__:Skipping Left-Amygdala-entropy_1min_mean: Insufficient samples for region Left-Amygdala (HUP: 4, MNI: 1)
# WARNING:__main__:Skipping Left-Amygdala-entropy_fullts_mean: Insufficient samples for region Left-Amygdala (HUP: 4, MNI: 1)
# INFO:__main__:Analyzing region: ctx-lh-caudalmiddlefrontal
# INFO:__main__:Analyzing region: ctx-rh-rostralanteriorcingulate
# WARNING:__main__:Skipping ctx-rh-rostralanteriorcingulate-deltaRel_mean: Insufficient samples for region ctx-rh-rostralanteriorcingulate (HUP: 1, MNI: 4)
# WARNING:__main__:Skipping ctx-rh-rostralanteriorcingulate-thetaRel_mean: Insufficient samples for region ctx-rh-rostralanteriorcingulate (HUP: 1, MNI: 4)
# WARNING:__main__:Skipping ctx-rh-rostralanteriorcingulate-alphaRel_mean: Insufficient samples for region ctx-rh-rostralanteriorcingulate (HUP: 1, MNI: 4)
# WARNING:__main__:Skipping ctx-rh-rostralanteriorcingulate-betaRel_mean: Insufficient samples for region ctx-rh-rostralanteriorcingulate (HUP: 1, MNI: 4)
# WARNING:__main__:Skipping ctx-rh-rostralanteriorcingulate-gammaRel_mean: Insufficient samples for region ctx-rh-rostralanteriorcingulate (HUP: 1, MNI: 4)
# WARNING:__main__:Skipping ctx-rh-rostralanteriorcingulate-entropy_1min_mean: Insufficient samples for region ctx-rh-rostralanteriorcingulate (HUP: 1, MNI: 4)
# WARNING:__main__:Skipping ctx-rh-rostralanteriorcingulate-entropy_fullts_mean: Insufficient samples for region ctx-rh-rostralanteriorcingulate (HUP: 1, MNI: 4)
# INFO:__main__:Analyzing region: ctx-lh-inferiortemporal
# INFO:__main__:Analyzing region: ctx-lh-parsopercularis
# INFO:__main__:Analyzing region: ctx-lh-middletemporal
# Loading HUP features from: ../results/ge_go_hup_region_features.csv
# Loading MNI features from: ../results/mni_region_features.csv
#
# Loaded data:
# HUP features shape: (398, 10)
# MNI features shape: (639, 10)
# Number of common regions: 57
# INFO:__main__:Analyzing region: Left-Hippocampus
# INFO:__main__:Analyzing region: ctx-lh-lateraloccipital
# WARNING:__main__:Skipping ctx-lh-lateraloccipital-deltaRel_mean: Insufficient samples for region ctx-lh-lateraloccipital (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-lh-lateraloccipital-thetaRel_mean: Insufficient samples for region ctx-lh-lateraloccipital (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-lh-lateraloccipital-alphaRel_mean: Insufficient samples for region ctx-lh-lateraloccipital (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-lh-lateraloccipital-betaRel_mean: Insufficient samples for region ctx-lh-lateraloccipital (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-lh-lateraloccipital-gammaRel_mean: Insufficient samples for region ctx-lh-lateraloccipital (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-lh-lateraloccipital-entropy_1min_mean: Insufficient samples for region ctx-lh-lateraloccipital (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-lh-lateraloccipital-entropy_fullts_mean: Insufficient samples for region ctx-lh-lateraloccipital (HUP: 3, MNI: 7)
# INFO:__main__:Analyzing region: Left-Putamen
# WARNING:__main__:Skipping Left-Putamen-deltaRel_mean: Insufficient samples for region Left-Putamen (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping Left-Putamen-thetaRel_mean: Insufficient samples for region Left-Putamen (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping Left-Putamen-alphaRel_mean: Insufficient samples for region Left-Putamen (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping Left-Putamen-betaRel_mean: Insufficient samples for region Left-Putamen (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping Left-Putamen-gammaRel_mean: Insufficient samples for region Left-Putamen (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping Left-Putamen-entropy_1min_mean: Insufficient samples for region Left-Putamen (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping Left-Putamen-entropy_fullts_mean: Insufficient samples for region Left-Putamen (HUP: 2, MNI: 3)
# INFO:__main__:Analyzing region: ctx-lh-posteriorcingulate
# WARNING:__main__:Skipping ctx-lh-posteriorcingulate-deltaRel_mean: Insufficient samples for region ctx-lh-posteriorcingulate (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-posteriorcingulate-thetaRel_mean: Insufficient samples for region ctx-lh-posteriorcingulate (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-posteriorcingulate-alphaRel_mean: Insufficient samples for region ctx-lh-posteriorcingulate (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-posteriorcingulate-betaRel_mean: Insufficient samples for region ctx-lh-posteriorcingulate (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-posteriorcingulate-gammaRel_mean: Insufficient samples for region ctx-lh-posteriorcingulate (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-posteriorcingulate-entropy_1min_mean: Insufficient samples for region ctx-lh-posteriorcingulate (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-posteriorcingulate-entropy_fullts_mean: Insufficient samples for region ctx-lh-posteriorcingulate (HUP: 1, MNI: 3)
# INFO:__main__:Analyzing region: ctx-rh-postcentral
# INFO:__main__:Analyzing region: ctx-lh-cuneus
# WARNING:__main__:Skipping ctx-lh-cuneus-deltaRel_mean: Insufficient samples for region ctx-lh-cuneus (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-cuneus-thetaRel_mean: Insufficient samples for region ctx-lh-cuneus (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-cuneus-alphaRel_mean: Insufficient samples for region ctx-lh-cuneus (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-cuneus-betaRel_mean: Insufficient samples for region ctx-lh-cuneus (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-cuneus-gammaRel_mean: Insufficient samples for region ctx-lh-cuneus (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-cuneus-entropy_1min_mean: Insufficient samples for region ctx-lh-cuneus (HUP: 2, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-cuneus-entropy_fullts_mean: Insufficient samples for region ctx-lh-cuneus (HUP: 2, MNI: 3)
# INFO:__main__:Analyzing region: ctx-lh-precuneus
# WARNING:__main__:Skipping ctx-lh-precuneus-deltaRel_mean: Insufficient samples for region ctx-lh-precuneus (HUP: 3, MNI: 10)
# WARNING:__main__:Skipping ctx-lh-precuneus-thetaRel_mean: Insufficient samples for region ctx-lh-precuneus (HUP: 3, MNI: 10)
# WARNING:__main__:Skipping ctx-lh-precuneus-alphaRel_mean: Insufficient samples for region ctx-lh-precuneus (HUP: 3, MNI: 10)
# WARNING:__main__:Skipping ctx-lh-precuneus-betaRel_mean: Insufficient samples for region ctx-lh-precuneus (HUP: 3, MNI: 10)
# WARNING:__main__:Skipping ctx-lh-precuneus-gammaRel_mean: Insufficient samples for region ctx-lh-precuneus (HUP: 3, MNI: 10)
# WARNING:__main__:Skipping ctx-lh-precuneus-entropy_1min_mean: Insufficient samples for region ctx-lh-precuneus (HUP: 3, MNI: 10)
# WARNING:__main__:Skipping ctx-lh-precuneus-entropy_fullts_mean: Insufficient samples for region ctx-lh-precuneus (HUP: 3, MNI: 10)
# INFO:__main__:Analyzing region: ctx-rh-lateraloccipital
# INFO:__main__:Analyzing region: ctx-rh-lateralorbitofrontal
# INFO:__main__:Analyzing region: ctx-rh-fusiform
# INFO:__main__:Analyzing region: ctx-rh-medialorbitofrontal
# INFO:__main__:Analyzing region: ctx-rh-parahippocampal
# WARNING:__main__:Skipping ctx-rh-parahippocampal-deltaRel_mean: Insufficient samples for region ctx-rh-parahippocampal (HUP: 5, MNI: 2)
# WARNING:__main__:Skipping ctx-rh-parahippocampal-thetaRel_mean: Insufficient samples for region ctx-rh-parahippocampal (HUP: 5, MNI: 2)
# WARNING:__main__:Skipping ctx-rh-parahippocampal-alphaRel_mean: Insufficient samples for region ctx-rh-parahippocampal (HUP: 5, MNI: 2)
# WARNING:__main__:Skipping ctx-rh-parahippocampal-betaRel_mean: Insufficient samples for region ctx-rh-parahippocampal (HUP: 5, MNI: 2)
# WARNING:__main__:Skipping ctx-rh-parahippocampal-gammaRel_mean: Insufficient samples for region ctx-rh-parahippocampal (HUP: 5, MNI: 2)
# WARNING:__main__:Skipping ctx-rh-parahippocampal-entropy_1min_mean: Insufficient samples for region ctx-rh-parahippocampal (HUP: 5, MNI: 2)
# WARNING:__main__:Skipping ctx-rh-parahippocampal-entropy_fullts_mean: Insufficient samples for region ctx-rh-parahippocampal (HUP: 5, MNI: 2)
# INFO:__main__:Analyzing region: ctx-lh-lingual
# WARNING:__main__:Skipping ctx-lh-lingual-deltaRel_mean: Insufficient samples for region ctx-lh-lingual (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-lingual-thetaRel_mean: Insufficient samples for region ctx-lh-lingual (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-lingual-alphaRel_mean: Insufficient samples for region ctx-lh-lingual (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-lingual-betaRel_mean: Insufficient samples for region ctx-lh-lingual (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-lingual-gammaRel_mean: Insufficient samples for region ctx-lh-lingual (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-lingual-entropy_1min_mean: Insufficient samples for region ctx-lh-lingual (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-lingual-entropy_fullts_mean: Insufficient samples for region ctx-lh-lingual (HUP: 3, MNI: 6)
# INFO:__main__:Analyzing region: Right-Hippocampus
# INFO:__main__:Analyzing region: ctx-rh-superiortemporal
# INFO:__main__:Analyzing region: ctx-rh-inferiortemporal
# INFO:__main__:Analyzing region: ctx-rh-superiorfrontal
# INFO:__main__:Analyzing region: ctx-lh-fusiform
# INFO:__main__:Analyzing region: ctx-lh-insula
# WARNING:__main__:Skipping ctx-lh-insula-deltaRel_mean: Insufficient samples for region ctx-lh-insula (HUP: 4, MNI: 12)
# WARNING:__main__:Skipping ctx-lh-insula-thetaRel_mean: Insufficient samples for region ctx-lh-insula (HUP: 4, MNI: 12)
# WARNING:__main__:Skipping ctx-lh-insula-alphaRel_mean: Insufficient samples for region ctx-lh-insula (HUP: 4, MNI: 12)
# WARNING:__main__:Skipping ctx-lh-insula-betaRel_mean: Insufficient samples for region ctx-lh-insula (HUP: 4, MNI: 12)
# WARNING:__main__:Skipping ctx-lh-insula-gammaRel_mean: Insufficient samples for region ctx-lh-insula (HUP: 4, MNI: 12)
# WARNING:__main__:Skipping ctx-lh-insula-entropy_1min_mean: Insufficient samples for region ctx-lh-insula (HUP: 4, MNI: 12)
# WARNING:__main__:Skipping ctx-lh-insula-entropy_fullts_mean: Insufficient samples for region ctx-lh-insula (HUP: 4, MNI: 12)
# INFO:__main__:Analyzing region: ctx-lh-inferiorparietal
# INFO:__main__:Analyzing region: ctx-lh-lateralorbitofrontal
# WARNING:__main__:Skipping ctx-lh-lateralorbitofrontal-deltaRel_mean: Insufficient samples for region ctx-lh-lateralorbitofrontal (HUP: 3, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-lateralorbitofrontal-thetaRel_mean: Insufficient samples for region ctx-lh-lateralorbitofrontal (HUP: 3, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-lateralorbitofrontal-alphaRel_mean: Insufficient samples for region ctx-lh-lateralorbitofrontal (HUP: 3, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-lateralorbitofrontal-betaRel_mean: Insufficient samples for region ctx-lh-lateralorbitofrontal (HUP: 3, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-lateralorbitofrontal-gammaRel_mean: Insufficient samples for region ctx-lh-lateralorbitofrontal (HUP: 3, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-lateralorbitofrontal-entropy_1min_mean: Insufficient samples for region ctx-lh-lateralorbitofrontal (HUP: 3, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-lateralorbitofrontal-entropy_fullts_mean: Insufficient samples for region ctx-lh-lateralorbitofrontal (HUP: 3, MNI: 9)
# INFO:__main__:Analyzing region: ctx-lh-postcentral
# INFO:__main__:Analyzing region: ctx-lh-parstriangularis
# INFO:__main__:Analyzing region: ctx-lh-precentral
# INFO:__main__:Analyzing region: ctx-rh-precuneus
# WARNING:__main__:Skipping ctx-rh-precuneus-deltaRel_mean: Insufficient samples for region ctx-rh-precuneus (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-rh-precuneus-thetaRel_mean: Insufficient samples for region ctx-rh-precuneus (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-rh-precuneus-alphaRel_mean: Insufficient samples for region ctx-rh-precuneus (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-rh-precuneus-betaRel_mean: Insufficient samples for region ctx-rh-precuneus (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-rh-precuneus-gammaRel_mean: Insufficient samples for region ctx-rh-precuneus (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-rh-precuneus-entropy_1min_mean: Insufficient samples for region ctx-rh-precuneus (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-rh-precuneus-entropy_fullts_mean: Insufficient samples for region ctx-rh-precuneus (HUP: 2, MNI: 9)
# INFO:__main__:Analyzing region: ctx-rh-parstriangularis
# INFO:__main__:Analyzing region: ctx-rh-lingual
# WARNING:__main__:Skipping ctx-rh-lingual-deltaRel_mean: Insufficient samples for region ctx-rh-lingual (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-rh-lingual-thetaRel_mean: Insufficient samples for region ctx-rh-lingual (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-rh-lingual-alphaRel_mean: Insufficient samples for region ctx-rh-lingual (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-rh-lingual-betaRel_mean: Insufficient samples for region ctx-rh-lingual (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-rh-lingual-gammaRel_mean: Insufficient samples for region ctx-rh-lingual (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-rh-lingual-entropy_1min_mean: Insufficient samples for region ctx-rh-lingual (HUP: 3, MNI: 7)
# WARNING:__main__:Skipping ctx-rh-lingual-entropy_fullts_mean: Insufficient samples for region ctx-rh-lingual (HUP: 3, MNI: 7)
# INFO:__main__:Analyzing region: ctx-lh-parsorbitalis
# WARNING:__main__:Skipping ctx-lh-parsorbitalis-deltaRel_mean: Insufficient samples for region ctx-lh-parsorbitalis (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-parsorbitalis-thetaRel_mean: Insufficient samples for region ctx-lh-parsorbitalis (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-parsorbitalis-alphaRel_mean: Insufficient samples for region ctx-lh-parsorbitalis (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-parsorbitalis-betaRel_mean: Insufficient samples for region ctx-lh-parsorbitalis (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-parsorbitalis-gammaRel_mean: Insufficient samples for region ctx-lh-parsorbitalis (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-parsorbitalis-entropy_1min_mean: Insufficient samples for region ctx-lh-parsorbitalis (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-parsorbitalis-entropy_fullts_mean: Insufficient samples for region ctx-lh-parsorbitalis (HUP: 1, MNI: 3)
# INFO:__main__:Analyzing region: ctx-lh-bankssts
# WARNING:__main__:Skipping ctx-lh-bankssts-deltaRel_mean: Insufficient samples for region ctx-lh-bankssts (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-lh-bankssts-thetaRel_mean: Insufficient samples for region ctx-lh-bankssts (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-lh-bankssts-alphaRel_mean: Insufficient samples for region ctx-lh-bankssts (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-lh-bankssts-betaRel_mean: Insufficient samples for region ctx-lh-bankssts (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-lh-bankssts-gammaRel_mean: Insufficient samples for region ctx-lh-bankssts (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-lh-bankssts-entropy_1min_mean: Insufficient samples for region ctx-lh-bankssts (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-lh-bankssts-entropy_fullts_mean: Insufficient samples for region ctx-lh-bankssts (HUP: 3, MNI: 8)
# INFO:__main__:Analyzing region: ctx-rh-insula
# WARNING:__main__:Skipping ctx-rh-insula-deltaRel_mean: Insufficient samples for region ctx-rh-insula (HUP: 3, MNI: 18)
# WARNING:__main__:Skipping ctx-rh-insula-thetaRel_mean: Insufficient samples for region ctx-rh-insula (HUP: 3, MNI: 18)
# WARNING:__main__:Skipping ctx-rh-insula-alphaRel_mean: Insufficient samples for region ctx-rh-insula (HUP: 3, MNI: 18)
# WARNING:__main__:Skipping ctx-rh-insula-betaRel_mean: Insufficient samples for region ctx-rh-insula (HUP: 3, MNI: 18)
# WARNING:__main__:Skipping ctx-rh-insula-gammaRel_mean: Insufficient samples for region ctx-rh-insula (HUP: 3, MNI: 18)
# WARNING:__main__:Skipping ctx-rh-insula-entropy_1min_mean: Insufficient samples for region ctx-rh-insula (HUP: 3, MNI: 18)
# WARNING:__main__:Skipping ctx-rh-insula-entropy_fullts_mean: Insufficient samples for region ctx-rh-insula (HUP: 3, MNI: 18)
# INFO:__main__:Analyzing region: ctx-rh-bankssts
# INFO:__main__:Analyzing region: ctx-rh-parsopercularis
# INFO:__main__:Analyzing region: ctx-lh-superiorparietal
# WARNING:__main__:Skipping ctx-lh-superiorparietal-deltaRel_mean: Insufficient samples for region ctx-lh-superiorparietal (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-superiorparietal-thetaRel_mean: Insufficient samples for region ctx-lh-superiorparietal (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-superiorparietal-alphaRel_mean: Insufficient samples for region ctx-lh-superiorparietal (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-superiorparietal-betaRel_mean: Insufficient samples for region ctx-lh-superiorparietal (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-superiorparietal-gammaRel_mean: Insufficient samples for region ctx-lh-superiorparietal (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-superiorparietal-entropy_1min_mean: Insufficient samples for region ctx-lh-superiorparietal (HUP: 2, MNI: 9)
# WARNING:__main__:Skipping ctx-lh-superiorparietal-entropy_fullts_mean: Insufficient samples for region ctx-lh-superiorparietal (HUP: 2, MNI: 9)
# INFO:__main__:Analyzing region: ctx-rh-rostralmiddlefrontal
# INFO:__main__:Analyzing region: ctx-lh-supramarginal
# INFO:__main__:Analyzing region: ctx-lh-rostralanteriorcingulate
# WARNING:__main__:Skipping ctx-lh-rostralanteriorcingulate-deltaRel_mean: Insufficient samples for region ctx-lh-rostralanteriorcingulate (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-rostralanteriorcingulate-thetaRel_mean: Insufficient samples for region ctx-lh-rostralanteriorcingulate (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-rostralanteriorcingulate-alphaRel_mean: Insufficient samples for region ctx-lh-rostralanteriorcingulate (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-rostralanteriorcingulate-betaRel_mean: Insufficient samples for region ctx-lh-rostralanteriorcingulate (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-rostralanteriorcingulate-gammaRel_mean: Insufficient samples for region ctx-lh-rostralanteriorcingulate (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-rostralanteriorcingulate-entropy_1min_mean: Insufficient samples for region ctx-lh-rostralanteriorcingulate (HUP: 3, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-rostralanteriorcingulate-entropy_fullts_mean: Insufficient samples for region ctx-lh-rostralanteriorcingulate (HUP: 3, MNI: 6)
# INFO:__main__:Analyzing region: ctx-rh-precentral
# INFO:__main__:Analyzing region: ctx-lh-medialorbitofrontal
# INFO:__main__:Analyzing region: Right-Amygdala
# WARNING:__main__:Skipping Right-Amygdala-deltaRel_mean: Insufficient samples for region Right-Amygdala (HUP: 2, MNI: 2)
# WARNING:__main__:Skipping Right-Amygdala-thetaRel_mean: Insufficient samples for region Right-Amygdala (HUP: 2, MNI: 2)
# WARNING:__main__:Skipping Right-Amygdala-alphaRel_mean: Insufficient samples for region Right-Amygdala (HUP: 2, MNI: 2)
# WARNING:__main__:Skipping Right-Amygdala-betaRel_mean: Insufficient samples for region Right-Amygdala (HUP: 2, MNI: 2)
# WARNING:__main__:Skipping Right-Amygdala-gammaRel_mean: Insufficient samples for region Right-Amygdala (HUP: 2, MNI: 2)
# WARNING:__main__:Skipping Right-Amygdala-entropy_1min_mean: Insufficient samples for region Right-Amygdala (HUP: 2, MNI: 2)
# WARNING:__main__:Skipping Right-Amygdala-entropy_fullts_mean: Insufficient samples for region Right-Amygdala (HUP: 2, MNI: 2)
# INFO:__main__:Analyzing region: ctx-rh-inferiorparietal
# INFO:__main__:Analyzing region: Right-Putamen
# WARNING:__main__:Skipping Right-Putamen-deltaRel_mean: Insufficient samples for region Right-Putamen (HUP: 2, MNI: 1)
# WARNING:__main__:Skipping Right-Putamen-thetaRel_mean: Insufficient samples for region Right-Putamen (HUP: 2, MNI: 1)
# WARNING:__main__:Skipping Right-Putamen-alphaRel_mean: Insufficient samples for region Right-Putamen (HUP: 2, MNI: 1)
# WARNING:__main__:Skipping Right-Putamen-betaRel_mean: Insufficient samples for region Right-Putamen (HUP: 2, MNI: 1)
# WARNING:__main__:Skipping Right-Putamen-gammaRel_mean: Insufficient samples for region Right-Putamen (HUP: 2, MNI: 1)
# WARNING:__main__:Skipping Right-Putamen-entropy_1min_mean: Insufficient samples for region Right-Putamen (HUP: 2, MNI: 1)
# WARNING:__main__:Skipping Right-Putamen-entropy_fullts_mean: Insufficient samples for region Right-Putamen (HUP: 2, MNI: 1)
# INFO:__main__:Analyzing region: ctx-lh-superiorfrontal
# WARNING:__main__:Skipping ctx-lh-superiorfrontal-deltaRel_mean: Insufficient samples for region ctx-lh-superiorfrontal (HUP: 4, MNI: 16)
# WARNING:__main__:Skipping ctx-lh-superiorfrontal-thetaRel_mean: Insufficient samples for region ctx-lh-superiorfrontal (HUP: 4, MNI: 16)
# WARNING:__main__:Skipping ctx-lh-superiorfrontal-alphaRel_mean: Insufficient samples for region ctx-lh-superiorfrontal (HUP: 4, MNI: 16)
# WARNING:__main__:Skipping ctx-lh-superiorfrontal-betaRel_mean: Insufficient samples for region ctx-lh-superiorfrontal (HUP: 4, MNI: 16)
# WARNING:__main__:Skipping ctx-lh-superiorfrontal-gammaRel_mean: Insufficient samples for region ctx-lh-superiorfrontal (HUP: 4, MNI: 16)
# WARNING:__main__:Skipping ctx-lh-superiorfrontal-entropy_1min_mean: Insufficient samples for region ctx-lh-superiorfrontal (HUP: 4, MNI: 16)
# WARNING:__main__:Skipping ctx-lh-superiorfrontal-entropy_fullts_mean: Insufficient samples for region ctx-lh-superiorfrontal (HUP: 4, MNI: 16)
# INFO:__main__:Analyzing region: ctx-rh-caudalmiddlefrontal
# INFO:__main__:Analyzing region: ctx-lh-superiortemporal
# INFO:__main__:Analyzing region: ctx-rh-parsorbitalis
# WARNING:__main__:Skipping ctx-rh-parsorbitalis-deltaRel_mean: Insufficient samples for region ctx-rh-parsorbitalis (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-rh-parsorbitalis-thetaRel_mean: Insufficient samples for region ctx-rh-parsorbitalis (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-rh-parsorbitalis-alphaRel_mean: Insufficient samples for region ctx-rh-parsorbitalis (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-rh-parsorbitalis-betaRel_mean: Insufficient samples for region ctx-rh-parsorbitalis (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-rh-parsorbitalis-gammaRel_mean: Insufficient samples for region ctx-rh-parsorbitalis (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-rh-parsorbitalis-entropy_1min_mean: Insufficient samples for region ctx-rh-parsorbitalis (HUP: 3, MNI: 8)
# WARNING:__main__:Skipping ctx-rh-parsorbitalis-entropy_fullts_mean: Insufficient samples for region ctx-rh-parsorbitalis (HUP: 3, MNI: 8)
# INFO:__main__:Analyzing region: ctx-rh-middletemporal
# INFO:__main__:Analyzing region: ctx-lh-paracentral
# WARNING:__main__:Skipping ctx-lh-paracentral-deltaRel_mean: Insufficient samples for region ctx-lh-paracentral (HUP: 1, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-paracentral-thetaRel_mean: Insufficient samples for region ctx-lh-paracentral (HUP: 1, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-paracentral-alphaRel_mean: Insufficient samples for region ctx-lh-paracentral (HUP: 1, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-paracentral-betaRel_mean: Insufficient samples for region ctx-lh-paracentral (HUP: 1, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-paracentral-gammaRel_mean: Insufficient samples for region ctx-lh-paracentral (HUP: 1, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-paracentral-entropy_1min_mean: Insufficient samples for region ctx-lh-paracentral (HUP: 1, MNI: 6)
# WARNING:__main__:Skipping ctx-lh-paracentral-entropy_fullts_mean: Insufficient samples for region ctx-lh-paracentral (HUP: 1, MNI: 6)
# INFO:__main__:Analyzing region: ctx-lh-rostralmiddlefrontal
# INFO:__main__:Analyzing region: ctx-lh-pericalcarine
# WARNING:__main__:Skipping ctx-lh-pericalcarine-deltaRel_mean: Insufficient samples for region ctx-lh-pericalcarine (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-pericalcarine-thetaRel_mean: Insufficient samples for region ctx-lh-pericalcarine (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-pericalcarine-alphaRel_mean: Insufficient samples for region ctx-lh-pericalcarine (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-pericalcarine-betaRel_mean: Insufficient samples for region ctx-lh-pericalcarine (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-pericalcarine-gammaRel_mean: Insufficient samples for region ctx-lh-pericalcarine (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-pericalcarine-entropy_1min_mean: Insufficient samples for region ctx-lh-pericalcarine (HUP: 1, MNI: 3)
# WARNING:__main__:Skipping ctx-lh-pericalcarine-entropy_fullts_mean: Insufficient samples for region ctx-lh-pericalcarine (HUP: 1, MNI: 3)
# INFO:__main__:Analyzing region: ctx-rh-superiorparietal
# INFO:__main__:Analyzing region: ctx-rh-supramarginal
# Regional Analysis Summary
# ==================================================
#
# Delta Band (0.5-4 Hz):
# - 0 regions show significant differences
#
# Theta Band (4-8 Hz):
# - 0 regions show significant differences
#
# Alpha Band (8-13 Hz):
# - 0 regions show significant differences
#
# Beta Band (13-30 Hz):
# - 0 regions show significant differences
#
# Gamma Band (30-80 Hz):
# - 0 regions show significant differences
#
# Signal Entropy (1-min):
# - 0 regions show significant differences
#
# Signal Entropy (full):
# - 0 regions show significant differences

# %% [markdown]
# ### DATASET DESCRIPTION

# %%
def analyze_regional_coverage():
    """
    Analyze regional coverage and patient counts in both cohorts
    """
    # Load data
    hup_features = pd.read_csv("../results/ge_go_hup_region_features.csv")
    mni_features = pd.read_csv("../results/mni_region_features.csv")
    
    print("\nHUP Dataset Analysis:")
    print("=" * 50)
    
    # Get patient and region counts for HUP
    hup_regions = hup_features.groupby('roi').agg({
        'patient_id': ['nunique', 'count']
    }).reset_index()
    hup_regions.columns = ['roi', 'n_patients', 'n_recordings']
    hup_regions = hup_regions.sort_values('n_patients', ascending=False)
    
    print(f"\nTotal unique regions in HUP: {len(hup_regions)}")
    print(f"Total unique patients in HUP: {hup_features['patient_id'].nunique()}")
    print("\nPatient counts per region (top 10):")
    print(hup_regions.head(10))
    
    print("\nRegions with < 5 patients:")
    print(hup_regions[hup_regions['n_patients'] < 5][['roi', 'n_patients']])
    
    print("\nMNI Dataset Analysis:")
    print("=" * 50)
    
    # Get patient and region counts for MNI
    mni_regions = mni_features.groupby('roi').agg({
        'patient_id': ['nunique', 'count']
    }).reset_index()
    mni_regions.columns = ['roi', 'n_patients', 'n_recordings']
    mni_regions = mni_regions.sort_values('n_patients', ascending=False)
    
    print(f"\nTotal unique regions in MNI: {len(mni_regions)}")
    print(f"Total unique patients in MNI: {mni_features['patient_id'].nunique()}")
    print("\nPatient counts per region (top 10):")
    print(mni_regions.head(10))
    
    print("\nRegions with < 5 patients:")
    print(mni_regions[mni_regions['n_patients'] < 5][['roi', 'n_patients']])
    
    # Analyze overlap
    common_regions = set(hup_regions['roi']) & set(mni_regions['roi'])
    print(f"\nOverlap Analysis:")
    print("=" * 50)
    print(f"Number of common regions: {len(common_regions)}")
    
    # Analyze which regions have sufficient patients in both cohorts
    valid_regions = []
    for region in common_regions:
        hup_patients = hup_regions[hup_regions['roi'] == region]['n_patients'].iloc[0]
        mni_patients = mni_regions[mni_regions['roi'] == region]['n_patients'].iloc[0]
        
        if hup_patients >= 5 and mni_patients >= 5:
            valid_regions.append({
                'region': region,
                'hup_patients': hup_patients,
                'mni_patients': mni_patients
            })
    
    print(f"\nRegions with ≥5 patients in both cohorts: {len(valid_regions)}")
    print("\nValid regions for paired analysis:")
    valid_df = pd.DataFrame(valid_regions)
    print(valid_df.sort_values('hup_patients', ascending=False))

if __name__ == "__main__":
    analyze_regional_coverage()
# Out:
# HUP Dataset Analysis:
# ==================================================
#
# Total unique regions in HUP: 67
# Total unique patients in HUP: 28
#
# Patient counts per region (top 10):
#                             roi  n_patients  n_recordings
# 61  ctx-rh-rostralmiddlefrontal          16            16
# 23        ctx-lh-middletemporal          15            15
# 17      ctx-lh-inferiortemporal          15            15
# 38      ctx-lh-superiortemporal          14            14
# 44              ctx-rh-fusiform          14            14
# 46      ctx-rh-inferiortemporal          13            13
# 52        ctx-rh-middletemporal          13            13
# 15              ctx-lh-fusiform          13            13
# 35  ctx-lh-rostralmiddlefrontal          13            13
# 58            ctx-rh-precentral          12            12
#
# Regions with < 5 patients:
#                                 roi  n_patients
# 18                    ctx-lh-insula           4
# 36           ctx-lh-superiorfrontal           4
# 0                     Left-Amygdala           4
# 47                    ctx-rh-insula           3
# 50                   ctx-rh-lingual           3
# 55             ctx-rh-parsorbitalis           3
# 33                 ctx-lh-precuneus           3
# 21                   ctx-lh-lingual           3
# 19          ctx-lh-lateraloccipital           3
# 34  ctx-lh-rostralanteriorcingulate           3
# 10                  ctx-lh-bankssts           3
# 4              Right-Accumbens-area           3
# 20      ctx-lh-lateralorbitofrontal           3
# 6                     Right-Caudate           2
# 9                     Right-Putamen           2
# 12                    ctx-lh-cuneus           2
# 37          ctx-lh-superiorparietal           2
# 14               ctx-lh-frontalpole           2
# 13                ctx-lh-entorhinal           2
# 5                    Right-Amygdala           2
# 25           ctx-lh-parahippocampal           2
# 3                      Left-Putamen           2
# 43                ctx-rh-entorhinal           2
# 59                 ctx-rh-precuneus           2
# 60  ctx-rh-rostralanteriorcingulate           1
# 2                     Left-Pallidum           1
# 40              ctx-lh-temporalpole           1
# 8                    Right-Pallidum           1
# 24               ctx-lh-paracentral           1
# 27             ctx-lh-parsorbitalis           1
# 29             ctx-lh-pericalcarine           1
# 31        ctx-lh-posteriorcingulate           1
# 66              ctx-rh-temporalpole           1
#
# MNI Dataset Analysis:
# ==================================================
#
# Total unique regions in MNI: 68
# Total unique patients in MNI: 106
#
# Patient counts per region (top 10):
#                             roi  n_patients  n_recordings
# 59            ctx-rh-precentral          25            25
# 62  ctx-rh-rostralmiddlefrontal          22            22
# 50        ctx-rh-middletemporal          21            21
# 34      ctx-lh-superiortemporal          20            20
# 44                ctx-rh-insula          18            18
# 42      ctx-rh-inferiorparietal          17            17
# 63       ctx-rh-superiorfrontal          16            16
# 53       ctx-rh-parsopercularis          16            16
# 32       ctx-lh-superiorfrontal          16            16
# 66         ctx-rh-supramarginal          16            16
#
# Regions with < 5 patients:
#                                 roi  n_patients
# 61  ctx-rh-rostralanteriorcingulate           4
# 40                    ctx-rh-cuneus           4
# 23             ctx-lh-parsorbitalis           3
# 25             ctx-lh-pericalcarine           3
# 56             ctx-rh-pericalcarine           3
# 27        ctx-lh-posteriorcingulate           3
# 45          ctx-rh-isthmuscingulate           3
# 3                      Left-Putamen           3
# 10                    ctx-lh-cuneus           3
# 52           ctx-rh-parahippocampal           2
# 4                    Right-Amygdala           2
# 1                      Left-Caudate           2
# 0                     Left-Amygdala           1
# 6                     Right-Putamen           1
# 67        ctx-rh-transversetemporal           1
#
# Overlap Analysis:
# ==================================================
# Number of common regions: 57
#
# Regions with ≥5 patients in both cohorts: 33
#
# Valid regions for paired analysis:
#                          region  hup_patients  mni_patients
# 22  ctx-rh-rostralmiddlefrontal            16            22
# 1       ctx-lh-inferiortemporal            15            13
# 3         ctx-lh-middletemporal            15            12
# 9               ctx-rh-fusiform            14            11
# 28      ctx-lh-superiortemporal            14            20
# 14              ctx-lh-fusiform            13             6
# 11      ctx-rh-inferiortemporal            13            11
# 29        ctx-rh-middletemporal            13            21
# 30  ctx-lh-rostralmiddlefrontal            13            14
# 24            ctx-rh-precentral            12            25
# 17      ctx-lh-parstriangularis            11            11
# 7   ctx-rh-lateralorbitofrontal            10            10
# 6            ctx-rh-postcentral            10            15
# 4              Left-Hippocampus            10             8
# 26      ctx-rh-inferiorparietal            10            17
# 19      ctx-rh-parstriangularis            10            11
# 21       ctx-rh-parsopercularis            10            16
# 8       ctx-rh-lateraloccipital             9            12
# 10            Right-Hippocampus             9             5
# 23         ctx-lh-supramarginal             9            13
# 15      ctx-lh-inferiorparietal             9             5
# 32         ctx-rh-supramarginal             9            16
# 27   ctx-rh-caudalmiddlefrontal             7            14
# 16           ctx-lh-postcentral             7             7
# 18            ctx-lh-precentral             7            14
# 2        ctx-lh-parsopercularis             7            12
# 20              ctx-rh-bankssts             6             5
# 25   ctx-lh-medialorbitofrontal             6            11
# 13       ctx-rh-superiorfrontal             6            16
# 12      ctx-rh-superiortemporal             5            15
# 5    ctx-rh-medialorbitofrontal             5            10
# 31      ctx-rh-superiorparietal             5            12
# 0    ctx-lh-caudalmiddlefrontal             5             8
